# %% [markdown]
# # Appendix A: POS Tagging Content

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

#from os import path
#from PIL import Image
#from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
text_df = pd.read_csv('/Users/lukasiwei/Desktop/dsi25-workspace/Projects/capstone_project/dataset/text_corpus.csv')

# %%
def preprocess_text(text):
    """ A function to lower and tokenize text data """ 
    # Lower the text
    lower_text = text.lower()

    # tokenize the text into a list of words
    tokens = nltk.tokenize.word_tokenize(lower_text)

    return tokens

# Final list with tokenized words
tokenized_final = []

# Iterating over each string in data
for x in text_df['text_column']:
    # Calliing preprocess text function
    token = preprocess_text(x)

    tokenized_final.append(token)

flattened_tokeninized_final = [i for j in tokenized_final for i in j]

postag_tokens = nltk.pos_tag(flattened_tokeninized_final)

# convert into dictionary
def convert(tup, di):
    for a, b in tup:
        di.setdefault(b, []).append(a)
    return di
      
dictionary = {}
convert(postag_tokens, dictionary)
# Out:
# {'NN': ['nothing',
#   'declare',
#   'today',
#   'beauty',
#   'lot',
#   'internet',
#   'i',
#   'use',
#   'today',
#   'i',
#   'winner',
#   'home',
#   'roller',
#   'lock',
#   'washer',
#   'work',
#   'right',
#   'muscara',
#   'okay',
#   'lot',
#   'beautiful',
#   'i',
#   'something',
#   'bit',
#   'track',
#   'something',
#   'internet',
#   'virus',
#   'goodness',
#   'buffalo',
#   'opinion',
#   'mr.',
#   'stick',
#   'time',
#   'idealist',
#   'number',
#   'line',
#   'nothing',
#   'right',
#   'nothing',
#   'okay',
#   'product',
#   'deal-breaker',
#   'skin',
#   'dick',
#   'self',
#   'i',
#   'way',
#   'i',
#   'doodle',
#   'god',
#   'cleansing',
#   'skin',
#   'vacuum',
#   'difference',
#   'rock',
#   'lady',
#   'god',
#   'face',
#   'i',
#   'okay',
#   'friday',
#   'chest',
#   'hair',
#   'comb',
#   'hair',
#   'something',
#   'song',
#   'hair',
#   'brush',
#   'iron',
#   'price',
#   'okay',
#   'time',
#   'fall',
#   'product',
# ...

# %% [markdown]
# # Dictionary content

# %%
print(dictionary['NN'])
# Out:
# ['nothing', 'declare', 'today', 'beauty', 'lot', 'internet', 'i', 'use', 'today', 'i', 'winner', 'home', 'roller', 'lock', 'washer', 'work', 'right', 'muscara', 'okay', 'lot', 'beautiful', 'i', 'something', 'bit', 'track', 'something', 'internet', 'virus', 'goodness', 'buffalo', 'opinion', 'mr.', 'stick', 'time', 'idealist', 'number', 'line', 'nothing', 'right', 'nothing', 'okay', 'product', 'deal-breaker', 'skin', 'dick', 'self', 'i', 'way', 'i', 'doodle', 'god', 'cleansing', 'skin', 'vacuum', 'difference', 'rock', 'lady', 'god', 'face', 'i', 'okay', 'friday', 'chest', 'hair', 'comb', 'hair', 'something', 'song', 'hair', 'brush', 'iron', 'price', 'okay', 'time', 'fall', 'product', 'hollywood', 'tape', 'face', 'look', 'hey', 'i', 'picture', 'god', 'god', 'god', 'way', 'product', 'list', 'skin', 'price', 'ok', 'google', 'i', 'fun', 'collagen', 'okay', 'video', 'work', 'date', 'middle', 'world', 'something', 'bit', 'station', 'couple', 'bullet', 'tik', 'tok', 'okay', 'satisfaction', 'w
# ...

# %%
print(dictionary['VBZ'])
# Out:
# ['is', "'s", 'has', 'does', "'s", "'s", 'is', "'s", 'is', 'is', 'is', 'is', "'s", "'s", "'s", 'is', "'s", 'is', 'is', 'is', 'is', 'does', "'s", 'looks', 'does', 'gets', 'is', 'is', 'is', 'is', 'is', "'s", "'s", 'is', 'uses', "'s", 'has', "'s", 'counts', "'s", "'s", 'is', 'is', 'is', 'sound', "'s", 'goes', 'is', 'is', 'is', 'is', 'has', 'comes', "'s", 'is', 'comes', 'is', "'s", 'is', "'s", "'s", 'is', 'is', 'is', 'is', 'boys', "'s", "'s", 'i', 'has', 'is', 'has', "'s", 'does', 'helps', 'works', 'works', 'is', 'is', 'is', 'does', 'does', 'is', 'is', 'has', 'is', 'is', 'is', 'is', 'does', "'s", 'is', "'s", 'is', 'thinks', "'s", "'s", 'is', 'falls', "'s", "'s", "'s", "'s", "'s", 'is', 'sounds', 'is', 'is', 'is', 'is', 'is', "'s", "'s", "'s", 'loves', "'s", "'s", 'is', "'s", 'is', "'s", 'is', 'stinks', 'works', "'s", "'s", 'is', 'is', "'s", 'is', 'is', 'is', 'is', 'is', 'is', 'i', 'is', 'is', 'i', 'is', 'is', 'is', 'does', 'feels', 'is', "'s", 'is', 'is', "'s", "'s", "'s", 'looks', "'s", 
# ...

# %%
print(dictionary['VBG'])
# Out:
# ['coming', 'going', 'trying', 'using', 'doing', 'according', 'trying', 'going', 'coming', 'hiding', 'going', 'doing', 'going', 'straightening', 'sagging', 'plumping', 'watching', 'putting', 'going', 'taking', 'being', 'rocking', 'going', 'being', 'trying', 'going', 'going', 'going', 'younging', 'being', 'welcoming', 'talking', 'being', 'trying', 'trying', 'struggling', 'sitting', 'going', 'trying', 'wearing', 'hearing', 'getting', 'pointing', 'pointing', 'doing', 'painting', 'waiting', 'doing', 'mentioning', 'painting', 'being', 'being', 'breaking', 'steering', 'breaking', 'expressing', 'expressing', 'going', 'practicing', 'casting', 'being', 'being', 'listening', 'doing', 'talking', 'being', 'seeing', 'growing', 'feeling', 'going', 'going', 'going', 'seeing', 'growing', 'being', 'having', 'going', 'going', 'going', 'giving', 'shutting', 'choosing', 'being', 'seeing', 'dealing', 'expressing', 'showing', 'growing', 'growing', 'trying', 'going', 'being', 'seeing', 'being', 'telling', '
# ...

# %%
print(dictionary['RP'])
# Out:
# ['out', 'out', 'up', 'out', 'down', 'out', 'up', 'out', 'along', 'down', 'out', 'up', 'up', 'up', 'up', 'up', 'back', 'out', 'up', 'up', 'up', 'out', 'up', 'back', 'out', 'down', 'up', 'over', 'up', 'up', 'up', 'out', 'off', 'down', 'up', 'out', 'off', 'off', 'out', 'out', 'out', 'up', 'out', 'out', 'out', 'out', 'out', 'up', 'out', 'out', 'back', 'up', 'up', 'out', 'down', 'away', 'up', 'down', 'off', 'off', 'out', 'out', 'out', 'out', 'out', 'up', 'up', 'out', 'out', 'out', 'up', 'up', 'out', 'out', 'down', 'out', 'out', 'out', 'up', 'up', 'down', 'out', 'out', 'out', 'out', 'up', 'up', 'off', 'up', 'up', 'out', 'out', 'up', 'out', 'up', 'out', 'off', 'up', 'out', 'over', 'out', 'out', 'up', 'out', 'up', 'out', 'up', 'out', 'up', 'off', 'up', 'away', 'up', 'up', 'up', 'online', 'up', 'out', 'up', 'up', 'out', 'off', 'up', 'out', 'b.', 'off', 'up', 'up', 'up', 'off', 'up', 'down', 'up', 'up', 'down', 'down', 'down', 'back', 'around', 'up', 'up', 'down', 'up', 'up', 'up', 'up', 'down
# ...

# %%
print(dictionary['RB'])
# Out:
# ['well', 'so', 'not', 'even', 'probably', 'properly', 'really', 'just', 'also', 'incredibly', 'too', 'far', 'even', 'here', 'even', 'definitely', 'so', 'late', 'almost', 'okay', 'even', 'already', 'so', 'just', "n't", 'maybe', 'then', 'back', 'right', 'instantly', 'already', 'pretty', 'first', "n't", 'already', 'very', 'right', 'now', 'actually', 'so', "n't", 'there', 'back', "n't", 'maybe', 'just', 'just', 'right', 'now', 'finally', 'very', 'ever', 'actually', 'very', 'always', 'far', 'right', 'back', 'together', 'essentially', 'so', 'still', 'as', 'soon', 'as', 'well', 'well', 'yours', 'together', 'just', 'very', 'just', 'down', 'never', "n't", 'right', 'so', 'really', 'not', "n't", 'really', 'especially', "n't", 'very', 'not', 'very', 'just', 'still', 'still', 'now', 'now', "n't", 'just', 'especially', 'as', 'well', 'right', 'now', 'away', 'again', 'as', 'well', 'right', 'not', 'not', 'right', 'now', 'even', 'back', 'back', "n't", "n't", 'as', 'much', 'so', 'there', 'too', 'not', 
# ...

# %%
print(dictionary['JJ'])
# Out:
# ['i', 'viral', 'new', 'other', 'interesting', 'native', 'right', 'much', 'i', 'i', 'recent', 'facial', 'i', 'wrong', 'i', 'ridiculous', 'viral', 'little', 'right', 'i', 'i', 'trimmer', 'much', 'next', 'dead', 'like', 'i', 'i', 'expensive', 'deep', 'blackhead', 'entire', 'next', 'easy', 'much', '5990', 'i', 'new', 'flat', 'i', 'i', 'multiple', 'right', 'much', 'i', 'right', 'right', 'linus', 'spicy', 'much', 'right', 'viral', 'immediate', 'inexpensive', 'okay', 'right', 'practical', 'right', 'much', 'next', 'welcome', 'special', 'welcome', 'young', "y'all", 'great', 'young', 'young-at-heart', 'nice', 'i', 'few', 'i', 'happy', 'mommy', 'unexpected', 'very', 'emotional', 'i', 'emotional', 'different', 'i', 'active', 'same', 'great', 'fallon', 'real', 'i', 'text', 'i', 'proud', 'same', 'mine', 'i', 'sure', 'instant', 'happy', 'worth', 'i', 'top', 'young', 'true', 'bad', 'soft', 'negative', 'i', 'traditional', 'indian', 'elderly', 'past', 'right', 'traditional', 'much', 'good', 'elderly',
# ...

# %%
print(dictionary['PRP'])
# Out:
# ['we', 'you', 'you', 'we', 'we', 'they', 'they', 'they', 'me', 'it', 'it', 'it', 'it', 'you', 'it', 'it', 'it', 'you', 'it', 'it', 'we', 'them', 'we', 'you', 'me', 'it', 'we', 'it', 'it', 'it', 'you', 'it', 'he', 'we', 'you', 'me', 'me', 'it', 'it', 'you', 'you', 'it', 'it', 'she', 'it', 'it', 'me', 'me', 'you', 'it', 'we', 'it', 'it', 'me', 'you', 'me', 'we', 'you', 'us', 'you', 'you', 'you', 'you', 'it', 'we', 'we', 'me', 'it', 'it', 'we', 'we', 'me', 'you', 'it', 'you', 'it', 'it', 'you', 'it', 'you', 'you', 'you', 'you', 'you', 'he', 'it', 'she', 'we', 'you', 'it', 'it', 'it', 'it', 'me', 'it', 'it', 'we', 'you', 'it', 'we', 'it', 'they', 'it', 'it', 'you', 'he', 'he', 'him', 'it', 'it', 'we', 'we', 'we', 'us', 'we', 'it', 'you', 'you', 'you', 'you', 'we', 'them', 'we', 'we', 'them', 'us', 'you', 'you', 'it', 'it', 'it', 'them', 'they', 'they', 'it', 'you', 'it', 'they', 'they', 'they', 'it', 'they', 'them', 'you', 'you', 'it', 'it', 'it', 'me', 'they', 'me', 'it', 'he', 'he', 'y
# ...

# %%
print(dictionary['VBP'])
# Out:
# ['are', 'look', 'think', 'think', 'see', 'know', 'are', 'guess', 'are', 'cost', "'ve", 'think', 'do', 'feel', 'want', 'think', 'do', 'buy', 'have', 'do', 'think', "'m", 'have', 'suck', 'think', "'m", 'think', 'think', "'m", 'spread', 'do', "'m", 'do', 'think', 'think', 'pull', 'think', 'are', 'do', 'are', 'like', 'do', 'do', 'have', 'look', 'do', 'have', 'are', 'are', "'ve", "'m", 'are', 'know', 'know', 'know', 'study', 'mean', 'dreams', 'are', 'say', "'m", "'m", "'m", "'m", 'do', 'have', 'talk', 'make', 'come', 'do', 'do', 'know', "'m", 'have', 'continue', 'think', "'re", 'have', 'do', 'try', 'do', "'re", 'try', "'ve", 'understand', 'want', 'have', 'go', 'are', 'consider', 'consider', 'know', 'want', 'i', 'feel', 'start', 'have', "'re", 'do', 'love', "'m", 'know', 'i', 'find', "'ve", 'know', 'understood', 'love', 'look', "'m", 'look', 'have', 'understand', 'have', 'know', 'understand', "'m", 'understand', 'have', 'have', 'have', 'know', 'wear', 'do', 'see', 'understand', "'re", "'re
# ...

# %%
print(dictionary['TO'])
# Out:
# ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', '
# ...

# %%
print(dictionary['VB'])
# Out:
# ['be', 'sweat', 'have', 'i', 'take', 'i', 'use', 'say', 'make', 'talk', 'buy', 'remove', 'hop', 'shaver', 'micro', 'remove', 'go', 'hit', 'see', 'have', 'call', 'show', 'guess', 'try', 'have', 'use', 'be', 'try', 'like', 'use', 'let', 'find', 'tighten', 'smile', 'tell', 'tell', 'let', 'watch', 'give', 'see', 'plump', 'think', 'mix', 'tell', 'buy', 'let', 'know', 'thank', 'forget', 'see', 'say', 'let', 'know', 'i', 'make', 'know', 'change', 'rodger', 'discuss', 'happen', 'push', 'try', 'be', 'do', 'know', 'happen', 'come', 'accept', 'take', 'eat', 'buy', 'eat', 'get', 'continue', 'talk', 'show', 'cry', 'cry', 'give', 'think', 'have', 'bring', 'reinvent', 'do', 'find', 'educate', 'have', 'unload', 'learn', 'bring', 'talk', 'listen', 'ease', 'talk', 'do', 'truth', 'i', 'see', 'say', 'give', 'i', 'get', 'wait', 'go', 'do', 'i', 'i', 'play', 'i', 'hold', 'express', 'stick', 'be', 'imagine', 'express', 'look', 'fall', 'do', 'fall', 'be', 'like', 'whatever', 'write', 'listen', 'be', 'need',
# ...

# %%
print(dictionary['DT'])
# Out:
# ['some', 'a', 'the', 'no', 'that', 'some', 'the', 'the', 'the', 'a', 'that', 'a', 'the', 'this', 'this', 'a', 'the', 'no', 'a', 'the', 'the', 'the', 'this', 'a', 'the', 'the', 'a', 'the', 'a', 'this', 'this', 'a', 'a', 'this', 'a', 'that', 'a', 'the', 'all', 'this', 'this', 'this', 'no', 'no', 'no', 'a', 'this', 'the', 'the', 'the', 'a', 'a', 'all', 'a', 'this', 'all', 'the', 'the', 'this', 'the', 'that', 'all', 'the', 'that', 'this', 'this', 'another', 'a', 'a', 'the', 'all', 'the', 'a', 'a', 'some', 'all', 'that', 'a', 'the', 'a', 'this', 'the', 'the', 'a', 'the', 'the', 'the', 'a', 'a', 'every', 'the', 'the', 'that', 'that', 'that', 'the', 'the', 'no', 'the', 'the', 'a', 'a', 'an', 'that', 'a', 'the', 'a', 'an', 'the', 'a', 'this', 'the', 'these', 'a', 'the', 'that', 'a', 'the', 'no', 'this', 'a', 'that', 'that', 'the', 'the', 'the', 'the', 'this', 'the', 'the', 'that', 'that', 'a', 'the', 'a', 'all', 'the', 'the', 'the', 'the', 'an', 'a', 'a', 'the', 'an', 'that', 'that', 'that',
# ...

# %%
print(dictionary['NNS'])
# Out:
# ['products', 'things', 'products', 'products', 'years', 'places', 'people', 'shadows', 'cells', 'i', 'promises', 'pieces', 'people', 'cameras', 'ideas', 'reasons', 'applies', 'minutes', 'minutes', 'lips', 'products', 'ladies', 'guys', 'ladies', 'guys', 'guests', 'emotions', 'kids', 'boys', 'things', 'babies', 'guys', 'moments', 'knows', 'days', 'dreams', 'i', 'noodles', 'minutes', 'noodles', 'searches', 'i', 'emotions', 'women', 'people', 'people', 'men', 'emotions', 'i', 'emotions', 'guys', 'statements', 'things', 'motions', 'emotions', 'things', 'generations', 'people', 'things', 'ways', 'nails', 'nails', 'nails', 'nephews', 'nieces', 'things', 'i', 'actions', 'things', 'men', 'nails', 'people', 'plays', 'words', 'parents', 'parents', 'emotions', 'peers', 'guys', 'styles', 'i', 'friends', 'insecurities', 'people', 'things', 'species', 'thoughts', 'thoughts', 'men', 'parents', 'feelings', 'balls', 'works', 'pushes', 'uncles', 'parents', 'victims', 'modes', 'men', 'times', 'sixties',
# ...

# %%
print(dictionary['IN'])
# Out:
# ['for', 'of', 'on', 'for', 'that', 'of', 'that', 'okay', 'in', 'like', 'that', 'if', 'of', 'about', 'off', 'without', 'so', 'on', 'in', 'that', 'in', 'like', 'of', 'before', 'between', 'through', 'before', 'through', 'so', 'for', 'though', 'with', 'of', 'as', 'like', 'for', 'in', 'over', 'like', 'for', 'for', 'so', 'on', 'at', 'like', 'in', 'below', 'with', 'for', 'of', 'if', 'like', 'though', 'on', 'at', 'that', 'in', 'that', 'on', 'because', 'out', 'of', 'that', 'in', 'with', 'of', 'of', 'so', 'that', 'that', 'of', 'for', 'because', 'about', 'like', 'like', 'in', 'like', 'for', 'for', 'so', 'like', 'that', 'that', 'like', 'of', 'on', 'as', 'on', 'off', 'in', 'on', 'of', 'that', 'that', 'with', 'about', 'about', 'with', 'that', 'though', 'like', 'like', 'while', 'in', 'that', 'like', 'from', 'for', 'of', 'for', 'with', 'from', 'than', 'for', 'for', 'that', 'that', 'about', 'for', 'like', 'that', 'with', 'about', 'in', 'that', 'from', 'with', 'as', 'because', 'if', 'that', 'about', '
# ...

# %%
print(dictionary['CC'])
# Out:
# ['and', 'but', 'and', 'and', 'and', 'and', 'but', 'but', 'and', 'and', 'but', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'but', 'and', 'but', 'and', 'and', 'but', 'and', 'but', 'but', 'and', 'and', 'and', 'and', 'but', 'and', 'and', 'and', 'and', 'and', 'but', 'and', 'and', 'but', 'but', 'and', 'but', 'and', 'and', 'and', 'but', 'and', 'and', 'and', 'and', 'or', 'but', 'and', 'but', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'or', 'and', 'and', 'and', 'and', 'and', 'and', 'but', 'and', 'and', 'and', 'and', 'but', 'and', 'but', 'and', 'and', 'and', 'but', 'but', 'and', 'but', 'and', 'or', 'or', 'and', 'and', 'and', 'but', 'and', 'and', 'but', 'and', 'but', 'and', 'and', 'and', 'and', 'but', 'but', '&', 'and', 'or', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'but', 'but', 'and', 'but', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'but', 'and', 'and', 'and', 'and', 'and', 'and', 'but', 'and', 'and', 'and', 'and', 'an
# ...

# %%
print(dictionary['MD'])
# Out:
# ['may', 'might', 'will', 'would', 'can', 'may', 'would', "'ll", 'would', 'would', 'will', 'might', 'can', 'can', "'ll", 'can', 'can', 'would', 'can', 'ca', 'may', 'can', 'can', 'may', 'can', 'can', 'can', 'would', 'can', "'ll", 'can', 'can', 'would', 'must', 'can', 'would', "'ll", 'can', 'can', 'can', 'would', 'can', 'will', 'will', 'should', 'should', 'should', 'can', 'must', 'would', 'can', 'can', 'should', 'could', 'should', 'can', 'should', 'can', 'will', 'can', "'ll", 'can', 'would', 'would', 'will', 'might', 'can', 'can', 'will', 'can', 'will', 'could', 'can', 'can', 'can', "'ll", 'will', "'ll", 'would', 'would', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'could', "'ll", 'would', 'can', 'would', 'can', 'can', 'would', 'would', 'will', 'will', 'can', 'can', 'can', 'could', 'can', 'will', 'will', "'ll", "'ll", 'can', 'can', 'can', 'can', "'ll", 'can', 'can', 'can', 'can', 'will', 'may', 'will', 'will', 'will', 'can', 'might', 'might', 'might', 'will', 'might', 'shoul
# ...

# %%
print(dictionary['WP'])
# Out:
# ['what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'who', 'what', 'what', 'who', 'what', 'what', 'what', 'what', 'what', 'who', 'what', 'what', 'what', 'what', 'what', 'what', 'who', 'what', 'whatever', 'who', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'who', 'who', 'what', 'who', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'who', 'what', 'who', 'what', 'what', 'what', 'who', 'what', 'who', 'what', 'what', 'what', 'what', 'who', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'who', 'who', 'who', 'what', 'who', 'who', 'what', 'what', 'who', 'who', 'what', 'what', 'who', 'what', 'what', 'what', 'who', 'what', 'who', 'what', 'what', 'what', 'who', 'what', 'what', 'who', 'who', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'who', 'wha
# ...

# %%
print(dictionary['WRB'])
# Out:
# ['how', 'when', 'when', 'how', 'where', 'how', 'how', 'how', 'how', 'how', 'when', 'why', 'how', 'how', 'when', 'when', 'when', 'when', 'where', 'where', 'why', 'why', 'how', 'how', 'how', 'where', 'where', 'when', 'when', 'how', 'why', 'how', 'how', 'how', 'how', 'how', 'why', 'when', 'when', 'when', 'when', 'when', 'when', 'when', 'how', 'where', 'how', 'why', 'how', 'why', 'where', 'when', 'how', 'how', 'how', 'how', 'how', 'where', 'how', 'how', 'whenever', 'when', 'how', 'how', 'where', 'where', 'where', 'how', 'how', 'when', 'when', 'why', 'how', 'how', 'when', 'how', 'how', 'how', 'when', 'how', 'how', 'when', 'when', 'how', 'how', 'when', 'when', 'when', 'how', 'where', 'where', 'how', 'when', 'how', 'how', 'how', 'when', 'how', 'when', 'how', 'how', 'how', 'when', 'when', 'how', 'when', 'how', 'why', 'when', 'how', 'why', 'how', 'how', 'why', 'how', 'when', 'how', 'when', 'when', 'how', 'when', 'when', 'when', 'how', 'why', 'where', 'why', 'how', 'where', 'where', 'how', 'wh
# ...

# %%
print(dictionary['VBN'])
# Out:
# ['tried', 'been', 'gone', 'been', 'been', 'occupied', 'been', 'done', 'learned', 'been', 'changed', 'painted', 'been', 'done', 'dreamed', 'liked', 'been', 'used', 'meant', 'been', 'conditioned', 'heard', 'ashamed', 'thought', 'learned', 'required', 'allowed', 'used', 'regarded', 'been', 'gone', 'seen', 'allowed', 'come', 'been', 'excited', 'been', 'seen', 'cried', 'thought', 'conditioned', 'named', 'dreamed', 'given', 'go', 'been', 'been', 'needed', 'made', 'upset', 'come', 'been', 'killed', 'done', 'prioritized', 'been', 'attached', 'been', 'passed', 'knew', 'discovered', 'ambushed', 'born', 'seen', 'tonight', 'faced', 'arrested', 'kicked', 'come', 'accepted', 'accepted', 'afraid', 'called', 'pissed', 'done', 'come', 'fight', 'lost', 'gone', 'put', 'satisfied', 'attracted', 'been', 'been', 'born', 'perpetuated', 'used', 'supposed', 'designed', 'become', 'invented', 'thought', 'come', 'learned', 'considered', 'given', 'gone', 'brought', 'met', 'removed', 'lied', 'done', 'caught', 'wo
# ...

# %%
print(dictionary['RBR'])
# Out:
# ['leather', 'more', 'more', 'more', 'better', 'more', 'more', 'more', 'more', 'less', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'better', 'more', 'more', 'more', 'more', 'more', 'more', 'matter', 'more', 'more', 'more', 'more', 'more', 'less', 'less', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'less', 'less', 'more', 'more', 'more', 'more', 'better', 'more', 'better', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'less', 'more', 'easier', 'more', 'more', 'more', 'more', 'more', 'better', 'more', 'better', 'more', 'more', 'more', 'better', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'less', 'more', 'more', 'more', 'more', 'more', 'deeper', 'more', 'more', 'more', 'better', 'more', 'longer', 'more', 'better', 'more', 'more', 'more', 'more', 'better', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'earlier', 'more', 'le
# ...

# %%
print(dictionary['CD'])
# Out:
# ['one', '95', '2022', '90', '33', '39900', '60.', '4290', '30', '60', 'one', '1990', '19', '3', 'one', 'one', 'five', 'one', 'one', '20', 'one', '70', 'one', '90s', '90', 'one', 'one', '60s', '321.', 'one', 'six', '25', 'three', 'one', 'two', '5', '10', '30', 'one', '5', '5', '6', '4', 'nine', 'one', '100', 'one', 'one', 'one', 'one', 'one', 'three', '1', 'three', 'six', 'one', 'five', '50.', '5', 'two', '21', 'six', 'two', '1', '0.5', 'three', '2121', '2021', '16', 'two', 'three', '45', '4', 'one', 'one', '20s', 'one', 'two', '3d', '27', '10', 'one', 'one', 'two', 'one', 'one', '80', 'one', 'one', '80', '85', '91', 'two', 'two', 'one', '2', 'two', '80', '1', '50', 'one', 'three', 'one', '5', '18', 'one', 'one', 'one', '1,000', '18', '18', '18', 'two', '11', 'one', '2015', '18', '24', 'one', 'three', 'four', '5:45', 'one', 'six', 'one', 'three', 'two', '1', '2', '27th', '30', 'two', '5', '5', '6', 'two', 'one', '97', '36', '1', '16', 'one', 'one', 'one', 'one', '7', 'one', 'one', '2'
# ...

# %%
print(dictionary['PRP$'])
# Out:
# ['my', 'your', 'my', 'your', 'my', 'your', 'my', 'my', 'my', 'my', 'your', 'my', 'our', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'his', 'his', 'my', 'my', 'my', 'my', 'my', 'their', 'my', 'my', 'my', 'your', 'your', 'your', 'your', 'my', 'his', 'his', 'your', 'my', 'my', 'my', 'my', 'my', 'my', 'her', 'my', 'my', 'his', 'my', 'my', 'my', 'my', 'my', 'her', 'your', 'your', 'your', 'their', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'my', 'his', 'your', 'their', 'your', 'our', 'my', 'his', 'my', 'my', 'my', 'your', 'their', 'their', 'your', 'their', 'my', 'their', 'their', 'their', 'your', 'my', 'my', 'your', 'your', 'their', 'her', 'your', 'our', 'our', 'your', 'your', 'my', 'your', 'my', 'your', 'my', 'my', 'my', 'my', 'my', 'my', 'your', 'my', 'your', 'my', 'my', 'my', 'my', 'your', 'my', 'my', 'my', 'my', 'their', 'your', 'your', 'my', 'my', 'his', 'your', 'our', 'my', 'our', 'our', 'his', 'our', 'my', 'your', 'your', 'your', 'your', 'your', 'my', 'my', 'my'
# ...

# %%
print(dictionary['JJS'])
# Out:
# ['finest', 'biggest', 'least', 'best', 'biggest', 'best', 'least', 'least', 'least', 'best', 'richest', 'best', 'most', 'lowest', 'best', 'chest', 'least', 'most', 'least', 'biggest', 'best', 'best', 'best', 'weirdest', 'biggest', 'biggest', 'least', 'most', 'skinniest', 'least', 'oldest', 'worst', 'greatest', 'meanest', 'best', 'honest', 'best', 'least', 'honest', 'least', 'loudest', 'most', 'nearest', 'best', 'closest', 'least', 'least', 'coldest', 'most', 'most', 'least', 'best', 'best', 'most', 'most', 'latest', 'best', 'least', 'most', 'least', 'honest', 'most', 'best', 'least', 'least', 'most', 'least', 'best', 'best', 'best', 'best', 'best', 'least', 'largest', 'best', 'oldest', 'worst', 'highest', 'honest', 'least', 'best', 'best', 'best', 'longest', 'best', 'best', 'best', 'best', 'best', 'best', 'best', 'best', 'best', 'best', 'honest', 'best', 'best', 'best', 'best', 'latest', 'biggest', 'most', 'most', 'pinterest', 'most', 'best', 'best', 'least', 'best', 'best', 'biggest
# ...

# %%
print(dictionary['UH'])
# Out:
# ['oh', 'oh', 'yes', 'oh', 'oh', 'oh', 'yes', 'oh', 'yeah', 'yeah', 'oh', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yes', 'oh', 'yeah', 'yeah', 'yeah', 'yeah', 'oh', 'yes', 'oh', 'yeah', 'yeah', 'yes', 'yes', 'yeah', 'yeah', 'yeah', 'oh', 'yes', 'yeah', 'yeah', 'yeah', 'yes', 'yes', 'yes', 'okay', 'yeah', 'oh', 'yeah', 'oh', 'yeah', 'okay', 'yeah', 'yeah', 'yeah', 'okay', 'yes', 'yeah', 'yeah', 'oh', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yes', 'yeah', 'yeah', 'oh', 'yeah', 'yeah', 'yeah', 'yeah', 'yes', 'yeah', 'yeah', 'yeah', 'yes', 'yes', 'yes', 'yeah', 'yes', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'yeah', 'oh', 'yeah', 'yeah', 'yeah', 'yeah', 'okay', 'oh', 'oh', 'yes', 'oh', 'oh', 'okay', 'yes', 'yes', 'yeah', 'knew', 'ok', 'yeah', 'oh', 'okay', 'oh', 'oh', 'yeah', 'yeah', 'oh', 'okay', 'yes', 'yeah', 'yeah', 'yeah', 'oh', 'yes',
# ...

# %%
print(dictionary['VBD'])
# Out:
# ['said', 'did', 'removed', 'got', 'put', 'did', 'knew', 'was', 'knew', 'was', 'cried', 'cried', 'were', 'was', 'was', 'was', 'saw', 'made', 'sat', 'had', 'came', 'was', 'was', 'was', 'was', 'abused', 'was', 'had', 'was', 'was', 'was', 'understood', 'understood', 'was', 'was', 'was', 'grew', 'used', 'was', 'grew', 'mentioned', 'were', 'had', 'were', 'were', 'talked', 'did', 'asked', 'came', 'did', 'was', 'was', 'felt', 'did', 'held', 'had', 'sold', 'was', 'made', 'was', 'said', 'was', 'did', 'grew', 'came', 'were', 'mentioned', 'did', 'had', 'grew', 'was', 'was', 'was', 'boots', 'was', 'knew', 'knew', 'knew', 'made', 'spent', 'knew', 'was', 'was', 'was', 'backed', 'said', 'had', 'did', 'mentioned', 'was', 'did', 'felt', 'questioned', 'brought', 'attached', 'did', 'said', 'was', 'read', 'did', 'did', 'discovered', 'did', 'was', 'were', 'was', 'went', 'used', 'said', 'had', 'halted', 'was', 'were', 'went', 'was', 'mentioned', 'put', 'got', 'won', 'came', 'said', 'was', 'were', 'invited'
# ...

# %%
print(dictionary['JJR'])
# Out:
# ['skinnier', 'more', 'better', 'better', 'better', 'less', 'smaller', 'younger', 'older', 'older', 'better', 'more', 'more', 'better', 'better', 'more', 'more', 'higher', 'more', 'more', 'more', 'less', 'more', 'easier', 'easier', 'bigger', 'better', 'better', 'more', 'more', 'older', 'older', 'younger', 'leisinger', 'younger', 'older', 'worse', 'older', 'more', 'older', 'bigger', 'better', 'more', 'more', 'bigger', 'more', 'more', 'bigger', 'longer', 'more', 'better', 'better', 'more', 'higher', 'younger', 'better', 'earlier', 'better', 'more', 'better', 'more', 'younger', 'finger', 'younger', 'older', 'younger', 'less', 'closer', 'more', 'happier', 'less', 'better', 'bigger', 'deeper', 'better', 'more', 'more', 'more', 'more', 'more', 'younger', 'tinier', 'better', 'more', 'more', 'more', 'smaller', 'more', 'larger', 'higher', 'more', 'lower', 'higher', 'outer', 'higher', 'better', 'more', 'younger', 'younger', 'lose', 'prettier', 'better', 'better', 'younger', 'better', 'more', 's
# ...

# %%
print(dictionary['POS'])
# Out:
# ["'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "'s", "
# ...

# %%
print(dictionary['WDT'])
# Out:
# ['that', 'which', 'that', 'whatever', 'that', 'that', 'that', 'whatever', 'which', 'which', 'that', 'that', 'which', 'that', 'whatever', 'that', 'that', 'which', 'whatever', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'which', 'whatever', 'that', 'that', 'that', 'that', 'that', 'which', 'that', 'that', 'that', 'that', 'that', 'whatever', 'whatever', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'which', 'that', 'which', 'that', 'that', 'that', 'which', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'whatever', 'that', 'which', 'that', 'that', 'that', 'that', 'what', 'that', 'that', 'that', 'which', 'which', 'that', 'that', 'that', 'that', 'whatever', 'that', 'which', 'that', 'that', 'that', 'which', 'whatever', 'whatever', 'that', 'that', 'that', 'that', 'that', 'which', 'that', 'whatever', 'that', 'whatever', 'whatever', 'that', 'that', 'that', 'that', 'that', 'that', 'which', 'that', 'which', 'which', 'whatever'
# ...

# %%
print(dictionary['PDT'])
# Out:
# ['all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'quite', 'all', 'all', 'all', 'all', 'all', 'all', 'quite', 'all', 'all', 'all', 'all', 'half', 'all', 'all', 'all', 'all', 'all', 'all', 'such', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'such', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'such', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'half', 'all', 'all', 'such', 'all', 'all', 'all', 'all', 'half', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'x.', 'all', 'all', 'all', 'write', 'all', 'all', 'all', 'all', 'half', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'half', 'all', 'all', 'all', 'such', 'all', 'all', 'such', 'all', 'all', 'all', '
# ...

# %%
print(dictionary['RBS'])
# Out:
# ['most', 'most', 'most', 'most', 'best', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'best', 'best', 'best', 'best', 'most', 'best', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'best', 'most', 'best', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'best', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most', 'most
# ...

# %%
print(dictionary['EX'])
# Out:
# ['there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there', 'there'
# ...

# %%
print(dictionary['FW'])
# Out:
# ['know', 'mm', 'girl', 'kitty', 'email', 'miss', 'ex', 'la', 'melissa', 'faria', 'vs', 'okay', 'ex', 'ex', 'i', 'volva', 'bono', 'love', 'explicit', 'er', 'evil', 'nina', 'numb', 'okay', 'numb', 'okay', 'vagina', 'vagina', 'make', 'michelle', 'linkin', 'okay', 'mother', 'nah', 'guys', 'okay', 'okay', 'i', 'i', 'i', 'pro', 'bono', 'sporadic', 'okay', 'shut', 'vs.', 'i', 'okay', 'megan', 'vs.', 'okay', 'akin', 'etc', 'i', 'skin', 'manna', 'okay', 'kl', 'magic', 'vs.', 'okay', 'vs.', 'know']

# %%
print(dictionary['NNP'])
# Out:
# ['zak', '/', 'kylie', 'x', '/', 'xcaret', 'malden', 'xp', 'kylie', 'know', 'klingon', '/', 'xc60', 'angina', 'youtuber', 'x.']

# %%
print(dictionary['WP$'])
# Out:
# ['whose', 'whose']

# %%
print(dictionary[','])
# Out:
# [',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',
# ...

# %%
print(dictionary["''"])
# Out:
# ['okay', 'yours', 'okay', 'esperanza', 'october', 'okay', 'evergarden']

# %%
print(dictionary['$'])
# Out:
# ['$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', 'rewind', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$', '$']

# %%
print(dictionary[':'])
# Out:
# ['-', '-', '-']
